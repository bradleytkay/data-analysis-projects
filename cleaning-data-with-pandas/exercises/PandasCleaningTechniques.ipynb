# %% [markdown]
# # Cleaning Data with Pandas Exercises
#
# For the exercises, you will be cleaning data in the Women's Clothing E-Commerce Reviews dataset.
#
# To start cleaning data, we first need to create a dataframe from the CSV and print out any relevant info to make sure our dataframe is ready to go.

# %%
# Import pandas and any other libraries you need here.

import pandas as pd

# Create a new dataframe from your CSV

df = pd.read_csv('Womens Clothing E-Commerce Reviews.csv')

# %%
# Print out any information you need to understand your dataframe

df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %% [markdown]
# ## Missing Data
#
# Try out different methods to locate and resolve missing data.

# %%
# Try to find some missing data!

df.isna()
# Out:
#        Unnamed: 0  Clothing ID    Age  Title  Review Text  Rating  \
# 0           False        False  False   True        False   False
# 1           False        False  False   True        False   False
# 2           False        False  False  False        False   False
# 3           False        False  False  False        False   False
# 4           False        False  False  False        False   False
# ...           ...          ...    ...    ...          ...     ...
# 23481       False        False  False  False        False   False
# 23482       False        False  False  False        False   False
# 23483       False        False  False  False        False   False
# 23484       False        False  False  False        False   False
# 23485       False        False  False  False        False   False
#
#        Recommended IND  Positive Feedback Count  Division Name  \
# 0                False                    False          False
# ...

# %% [markdown]
# Did you find any missing data? What things worked well for you and what did not?

# %%
df.dropna()

# Respond to the above questions here:

# Have we learned any methods for finding missing data in pandas other than .isna()
# (and I suppose it's counterpart .isnull())?  I didn't find any others when re-
# reading through the Handling Missing Data chapter in the textbook...
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# 5               5         1080   49
# 6               6          858   39
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# 5                                Not for the very petite
# 6                                   Cagrcoal shimmer fun
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %% [markdown]
# ## Irregular Data
#
# With missing data out of the way, turn your attention to any outliers. Just as we did for missing data, we first need to detect the outliers.

# %%
# Keep an eye out for outliers!
import matplotlib.pyplot as plt 

df.plot.hist(column = 'Rating')
plt.show()

df.boxplot(column = 'Rating')

Q1 = df['Rating'].quantile(0.25)
Q3 = df['Rating'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['Rating'] < (Q1 - 1.5 * IQR)) | ((df['Rating'] > Q3 + 1.5 * IQR))]

outliers
# Out:
#        Unnamed: 0  Clothing ID  Age                            Title  \
# 5               5         1080   49          Not for the very petite
# 22             22         1077   31           Not what it looks like
# 26             26          949   33              Huge disappointment
# 33             33          949   36                             Mehh
# 56             56          368   33                              NaN
# ...           ...          ...  ...                              ...
# 23406       23406         1082   68                     Disappointed
# 23424       23424          854   58                 Extremely sheer!
# 23427       23427          854   42                      Sheer shirt
# 23437       23437         1104   59  Not typical of retailer quality
# 23478       23478         1104   32                     Unflattering
#
#                                              Review Text  Rating  \
# 5      I love tracy reese dresses, but this one is no...       2
# ...

# %% [markdown]
# What techniques helped you find outliers? In your opinion, what about the techniques you used made them effective?

# %%
# Make your notes here:

# Visual analysis using histogram and box-and-whisker plot AND data analysis using IQR
# appear to BOTH reveal that ratings of 1 and 2 are outliers in this dataset.  That seems
# strange to me, though.  Like... you can't just throw out ratings of 1 or 2 because there
# are few of them, right?  They still seem like important parts of the dataset to me...


# I wonder what's true for age?  It looks like anything over 80 is an outlier? 

df.plot.hist(column = 'Age')
plt.show()

df.boxplot(column = 'Age')

Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['Age'] < (Q1 - 1.5 * IQR)) | ((df['Age'] > Q3 + 1.5 * IQR))]

outliers
# Out:
#        Unnamed: 0  Clothing ID  Age                         Title  \
# 95             95          863   83              Casual elegance!
# 234           234          840   83        Pretty but runs large!
# 277           277          868   83              Sooooooooo cute!
# 628           628         1059   80             Please restock!!!
# 659           659          252   93                 Amazing suit!
# ...           ...          ...  ...                           ...
# 22640       22640         1094   80             Fantastic product
# 22716       22716         1087   87                           NaN
# 22773       22773          949   83              Scottish classic
# 23001       23001          298   83  Beautiful twist on a classic
# 23033       23033          868   86                  Loved these!
#
#                                              Review Text  Rating  \
# 95     Purchased this top online, and when i received...       5
# ...

# %% [markdown]
# ## Unnecessary Data
#
# Unnecessary data could be irrelevant to your analysis or a duplice column. Check out the dataset to see if there is any unnecessary data.

# %%
# Look out for unnecessary data!

df.drop(columns = ['Unnamed: 0', 'Title', 'Review Text', 'Division Name', 'Department Name'])
# Out:
#        Clothing ID  Age  Rating  Recommended IND  Positive Feedback Count  \
# 0              767   33       4                1                        0
# 1             1080   34       5                1                        4
# 2             1077   60       3                0                        0
# 3             1049   50       5                1                        0
# 4              847   47       5                1                        6
# ...            ...  ...     ...              ...                      ...
# 23481         1104   34       5                1                        0
# 23482          862   48       3                1                        0
# 23483         1104   31       3                0                        1
# 23484         1084   28       3                1                        2
# 23485         1104   52       5                1                       22
#
#       Class Name
# 0      Intimates
# 1        Dresses
# 2        Dresses
# ...

# %% [markdown]
# Did you find any unnecessary data in your dataset? How did you handle it?

# %%
# Make your notes here.

# I .drop()-ed columns that contained strings that didn't seem like they would add anything
# to a visualization or to knowledge of connecting ratings to specific products.

# %% [markdown]
# ## Inconsistent Data
#
# Inconsistent data is likely due to inconsistent formatting and can be addressed by re-formatting all values in a column or row.

# %%
# Look out for inconsistent data!

df['Recommended IND'] = df['Recommended IND'].astype(bool)

df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4             True
# 1  Love this dress!  it's sooo pretty.  i happene...       5             True
# 2  I had such high hopes for this dress and reall...       3            False
# 3  I love, love, love this jumpsuit. it's fun, fl...       5             True
# 4  This shirt is very flattering to all due to th...       5             True
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %% [markdown]
# Did you find any inconsistent data? What did you do to clean it?

# %%
# Make your notes here!

# I didn't find any 'inconsistent' data per se, but as the chapter in the textbook on
# handling inconsistent data had us deal with 0s and 1s / Trues and Falses, I thought
# I'd try to convert the 'Recommended IND' column from ints to bools.
