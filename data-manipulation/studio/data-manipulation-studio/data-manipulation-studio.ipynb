# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!

import pandas as pd
import numpy as np 

df_bal = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/baltimore_9-24-2016_9-30-2017.csv')
df_bos = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/boston_9-24-2016_9-30-2017.csv')
df_ny = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/new-york_9-24-2016_9-30-2017.csv')
df_phil = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/philadelphia_9-24-2016_9-30-2017.csv')

df_bal.head()
df_bos.head()
df_ny.head()
df_phil.head()
# Out:
#   Commodity Name     City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  PHILADELPHIA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/16/2017        140         150  ...    NaN          NaN
# 1    NaN  09/24/2016        150         150  ...    NaN          NaN
# 2    NaN  09/24/2016        150         150  ...    NaN          NaN
# 3    NaN  09/24/2016        150         160  ...    NaN          NaN
# 4    NaN  10/01/2016        140         140  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage Crop  Repack  \
# 0          NaN      NaN       NaN         NaN      NaN  NaN       N
# 1          NaN      NaN       NaN         NaN      NaN  NaN       N
# 2          NaN      NaN       NaN         NaN      NaN  NaN       N
# 3          NaN      NaN       NaN         NaN      NaN  NaN       N
# 4          NaN      NaN       NaN         NaN      NaN  NaN       N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!

df_bal = df_bal.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 
df_bos = df_bos.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 
df_ny = df_ny.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 
df_phil = df_phil.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 

df_bal.shape
df_bos.shape
df_ny.shape
df_phil.shape
# Out:
# (57, 23)

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!

df_ne = pd.concat([df_bal, df_bos, df_ny, df_phil])

df_ne.shape
# Out:
# (674, 23)

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.

df_ne_grouped_package = df_ne.groupby('Package')
df_ne_grouped_package.agg({'Low Price': 'mean', 'High Price': 'mean'})
# Out:
#                        Low Price  High Price
# Package
# 1 1/9 bushel cartons   15.875000   16.739583
# 1 1/9 bushel crates    16.058824   16.705882
# 1/2 bushel cartons     16.030928   17.597938
# 24 inch bins          188.005618  202.808989
# 36 inch bins          170.458861  196.550633
# 50 lb sacks            25.111111   25.333333
# bushel cartons         20.571429   22.857143
# each                   75.000000   80.000000

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.

df_ne_grouped_market = df_ne.groupby(['City Name', 'Variety'])

df_ne_grouped_market.count()

# is count the right function to call here to get the desired result?
# Out:
#                                        Commodity Name  Type  Package  \
# City Name    Variety
# BALTIMORE    BIG MACK TYPE                         24     0       24
#              CINDERELLA                            25     0       25
#              FAIRYTALE                             16     0       16
#              HOWDEN TYPE                           25     0       25
#              HOWDEN WHITE TYPE                      2     0        2
#              MINIATURE                             30     0       30
#              MIXED HEIRLOOM VARIETIES               3     0        3
#              PIE TYPE                              26     0       26
# BOSTON       BIG MACK TYPE                         29     0       29
#              BLUE TYPE                              7     0        7
#              CINDERELLA                            14     0       14
#              FAIRYTALE                             21     0       21
#              HOWDEN TYPE                          132     0      132
#              KNUCKLE HEAD                           7     0        7
#              MINIATURE                             28     0       28
#              PIE TYPE                             114     0      114
# NEW YORK     BIG MACK TYPE                          2     0        2
#              HOWDEN TYPE                           39     0       39
#              KNUCKLE HEAD                           1     0        1
#              MINIATURE                             27     0       27
#              MIXED HEIRLOOM VARIETIES               1     0        1
#              PIE TYPE                              42     0       42
# PHILADELPHIA HOWDEN TYPE                           28     0       28
#              KNUCKLE HEAD                           1     0        1
#              MINIATURE                             12     0       12
#              PIE TYPE                              16     0       16
#
#                                        Sub Variety  Date  Low Price  \
# City Name    Variety
# BALTIMORE    BIG MACK TYPE                       0    24         24
#              CINDERELLA                          0    25         25
#              FAIRYTALE                           0    16         16
#              HOWDEN TYPE                         0    25         25
#              HOWDEN WHITE TYPE                   0     2          2
#              MINIATURE                          25    30         30
#              MIXED HEIRLOOM VARIETIES            0     3          3
#              PIE TYPE                            0    26         26
# BOSTON       BIG MACK TYPE                       0    29         29
#              BLUE TYPE                           0     7          7
#              CINDERELLA                          0    14         14
#              FAIRYTALE                           0    21         21
#              HOWDEN TYPE                         0   132        132
#              KNUCKLE HEAD                        0     7          7
#              MINIATURE                          28    28         28
#              PIE TYPE                            0   114        114
# NEW YORK     BIG MACK TYPE                       0     2          2
#              HOWDEN TYPE                         0    39         39
#              KNUCKLE HEAD                        0     1          1
#              MINIATURE                          18    27         27
#              MIXED HEIRLOOM VARIETIES            0     1          1
#              PIE TYPE                            0    42         42
# PHILADELPHIA HOWDEN TYPE                         0    28         28
#              KNUCKLE HEAD                        0     1          1
#              MINIATURE                          12    12         12
#              PIE TYPE                            0    16         16
#
#                                        High Price  Mostly Low  Mostly High  \
# City Name    Variety
# BALTIMORE    BIG MACK TYPE                     24          24           24
#              CINDERELLA                        25          25           25
#              FAIRYTALE                         16          16           16
#              HOWDEN TYPE                       25          25           25
#              HOWDEN WHITE TYPE                  2           2            2
#              MINIATURE                         30          30           30
#              MIXED HEIRLOOM VARIETIES           3           3            3
#              PIE TYPE                          26          26           26
# BOSTON       BIG MACK TYPE                     29          29           29
#              BLUE TYPE                          7           7            7
#              CINDERELLA                        14          14           14
#              FAIRYTALE                         21          21           21
#              HOWDEN TYPE                      132         132          132
#              KNUCKLE HEAD                       7           7            7
#              MINIATURE                         28          28           28
#              PIE TYPE                         114         114          114
# NEW YORK     BIG MACK TYPE                      2           2            2
#              HOWDEN TYPE                       39          39           39
#              KNUCKLE HEAD                       1           1            1
#              MINIATURE                         27          27           27
#              MIXED HEIRLOOM VARIETIES           1           1            1
#              PIE TYPE                          42          42           42
# PHILADELPHIA HOWDEN TYPE                       28          28           28
#              KNUCKLE HEAD                       1           1            1
#              MINIATURE                         12          12           12
#              PIE TYPE                          16          16           16
#
#                                        Origin  ...  Color  Environment  \
# City Name    Variety                           ...
# BALTIMORE    BIG MACK TYPE                 24  ...      8            0
#              CINDERELLA                    22  ...      0            0
#              FAIRYTALE                     16  ...      0            0
#              HOWDEN TYPE                   25  ...      4            0
#              HOWDEN WHITE TYPE              2  ...      0            0
#              MINIATURE                     30  ...     11            0
#              MIXED HEIRLOOM VARIETIES       3  ...      0            0
#              PIE TYPE                      26  ...      8            0
# BOSTON       BIG MACK TYPE                 29  ...      7            0
#              BLUE TYPE                      7  ...      7            0
#              CINDERELLA                    14  ...     14            0
#              FAIRYTALE                     21  ...     21            0
#              HOWDEN TYPE                  132  ...    120            0
#              KNUCKLE HEAD                   7  ...      7            0
#              MINIATURE                     28  ...     28            0
#              PIE TYPE                     114  ...    100            0
# NEW YORK     BIG MACK TYPE                  2  ...      0            0
#              HOWDEN TYPE                   39  ...      0            0
#              KNUCKLE HEAD                   1  ...      0            0
#              MINIATURE                     27  ...      9            0
#              MIXED HEIRLOOM VARIETIES       1  ...      0            0
#              PIE TYPE                      42  ...     12            0
# PHILADELPHIA HOWDEN TYPE                   28  ...      0            0
#              KNUCKLE HEAD                   1  ...      0            0
#              MINIATURE                     12  ...      0            0
#              PIE TYPE                      16  ...      0            0
#
#                                        Unit of Sale  Quality  Condition  \
# City Name    Variety
# BALTIMORE    BIG MACK TYPE                       24        0          0
#              CINDERELLA                           0        0          0
#              FAIRYTALE                            0        0          0
#              HOWDEN TYPE                          0        0          0
#              HOWDEN WHITE TYPE                    0        0          0
#              MINIATURE                            0        0          0
#              MIXED HEIRLOOM VARIETIES             0        0          0
#              PIE TYPE                             0        0          0
# BOSTON       BIG MACK TYPE                       22        0          0
#              BLUE TYPE                            0        0          0
#              CINDERELLA                           0        0          0
#              FAIRYTALE                            0        0          0
#              HOWDEN TYPE                         12        0          0
#              KNUCKLE HEAD                         0        0          0
#              MINIATURE                            0        0          0
#              PIE TYPE                            12        0          0
# NEW YORK     BIG MACK TYPE                        0        0          0
#              HOWDEN TYPE                         13        0          0
#              KNUCKLE HEAD                         0        0          0
#              MINIATURE                            0        0          0
#              MIXED HEIRLOOM VARIETIES             0        0          0
#              PIE TYPE                            12        0          0
# PHILADELPHIA HOWDEN TYPE                          0        0          0
#              KNUCKLE HEAD                         0        0          0
#              MINIATURE                           11        0          0
#              PIE TYPE                             0        0          0
#
#                                        Appearance  Storage  Crop  Repack  \
# City Name    Variety
# BALTIMORE    BIG MACK TYPE                      0        0     0      24
#              CINDERELLA                         0        0     0      25
#              FAIRYTALE                          0        0     0      16
#              HOWDEN TYPE                        0        0     0      25
#              HOWDEN WHITE TYPE                  0        0     0       2
#              MINIATURE                          0        0     0      30
#              MIXED HEIRLOOM VARIETIES           0        0     0       3
#              PIE TYPE                           0        0     0      26
# BOSTON       BIG MACK TYPE                      0        0     0      29
#              BLUE TYPE                          0        0     0       7
#              CINDERELLA                         0        0     0      14
#              FAIRYTALE                          0        0     0      21
#              HOWDEN TYPE                        0        0     0     132
#              KNUCKLE HEAD                       0        0     0       7
#              MINIATURE                          0        0     0      28
#              PIE TYPE                           0        0     0     114
# NEW YORK     BIG MACK TYPE                      0        0     0       2
#              HOWDEN TYPE                        0        0     0      39
#              KNUCKLE HEAD                       0        0     0       1
#              MINIATURE                          0        0     0      27
#              MIXED HEIRLOOM VARIETIES           0        0     0       1
#              PIE TYPE                           0        0     0      42
# PHILADELPHIA HOWDEN TYPE                        0        0     0      28
#              KNUCKLE HEAD                       0        0     0       1
#              MINIATURE                          0        0     0      12
#              PIE TYPE                           0        0     0      16
#
#                                        Trans Mode
# City Name    Variety
# BALTIMORE    BIG MACK TYPE                      0
#              CINDERELLA                         0
#              FAIRYTALE                          0
#              HOWDEN TYPE                        0
#              HOWDEN WHITE TYPE                  0
#              MINIATURE                          0
#              MIXED HEIRLOOM VARIETIES           0
#              PIE TYPE                           0
# BOSTON       BIG MACK TYPE                      0
#              BLUE TYPE                          0
#              CINDERELLA                         0
#              FAIRYTALE                          0
#              HOWDEN TYPE                        0
#              KNUCKLE HEAD                       0
#              MINIATURE                          0
#              PIE TYPE                           0
# NEW YORK     BIG MACK TYPE                      0
#              HOWDEN TYPE                        0
#              KNUCKLE HEAD                       0
#              MINIATURE                          0
#              MIXED HEIRLOOM VARIETIES           0
#              PIE TYPE                           0
# PHILADELPHIA HOWDEN TYPE                        0
#              KNUCKLE HEAD                       0
#              MINIATURE                          0
#              PIE TYPE                           0
#
# [26 rows x 21 columns]

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!

df_chi = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/chicago_9-24-2016_9-30-2017.csv')
df_det = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/detroit_9-24-2016_9-30-2017.csv')
df_stl = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/st-louis_9-24-2016_9-30-2017.csv')

df_chi = df_bal.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 
df_det = df_bos.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 
df_stl = df_stl.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 

df_mw = pd.concat([df_chi, df_det, df_stl])

df_mw_grouped_package = df_mw.groupby('Package')
df_mw_grouped_package.agg({'Low Price': 'mean', 'High Price': 'mean'})

df_mw_grouped_market = df_mw.groupby(['City Name', 'Variety'])
df_mw_grouped_market.count()
# Out:
#                                     Commodity Name  Type  Package  \
# City Name Variety
# BALTIMORE BIG MACK TYPE                         24     0       24
#           CINDERELLA                            25     0       25
#           FAIRYTALE                             16     0       16
#           HOWDEN TYPE                           25     0       25
#           HOWDEN WHITE TYPE                      2     0        2
#           MINIATURE                             30     0       30
#           MIXED HEIRLOOM VARIETIES               3     0        3
#           PIE TYPE                              26     0       26
# BOSTON    BIG MACK TYPE                         29     0       29
#           BLUE TYPE                              7     0        7
#           CINDERELLA                            14     0       14
#           FAIRYTALE                             21     0       21
#           HOWDEN TYPE                          132     0      132
#           KNUCKLE HEAD                           7     0        7
#           MINIATURE                             28     0       28
#           PIE TYPE                             114     0      114
# ST. LOUIS HOWDEN TYPE                           40     0       40
#           HOWDEN WHITE TYPE                      5     0        5
#           MINIATURE                             38     0       38
#           MIXED HEIRLOOM VARIETIES              10     0       10
#           PIE TYPE                              10     0       10
#
#                                     Sub Variety  Date  Low Price  High Price  \
# City Name Variety
# BALTIMORE BIG MACK TYPE                       0    24         24          24
#           CINDERELLA                          0    25         25          25
#           FAIRYTALE                           0    16         16          16
#           HOWDEN TYPE                         0    25         25          25
#           HOWDEN WHITE TYPE                   0     2          2           2
#           MINIATURE                          25    30         30          30
#           MIXED HEIRLOOM VARIETIES            0     3          3           3
#           PIE TYPE                            0    26         26          26
# BOSTON    BIG MACK TYPE                       0    29         29          29
#           BLUE TYPE                           0     7          7           7
#           CINDERELLA                          0    14         14          14
#           FAIRYTALE                           0    21         21          21
#           HOWDEN TYPE                         0   132        132         132
#           KNUCKLE HEAD                        0     7          7           7
#           MINIATURE                          28    28         28          28
#           PIE TYPE                            0   114        114         114
# ST. LOUIS HOWDEN TYPE                         0    40         40          40
#           HOWDEN WHITE TYPE                   0     5          5           5
#           MINIATURE                          38    38         38          38
#           MIXED HEIRLOOM VARIETIES            0    10         10          10
#           PIE TYPE                            0    10         10          10
#
#                                     Mostly Low  Mostly High  Origin  ...  \
# City Name Variety                                                    ...
# BALTIMORE BIG MACK TYPE                     24           24      24  ...
#           CINDERELLA                        25           25      22  ...
#           FAIRYTALE                         16           16      16  ...
#           HOWDEN TYPE                       25           25      25  ...
#           HOWDEN WHITE TYPE                  2            2       2  ...
#           MINIATURE                         30           30      30  ...
#           MIXED HEIRLOOM VARIETIES           3            3       3  ...
#           PIE TYPE                          26           26      26  ...
# BOSTON    BIG MACK TYPE                     29           29      29  ...
#           BLUE TYPE                          7            7       7  ...
#           CINDERELLA                        14           14      14  ...
#           FAIRYTALE                         21           21      21  ...
#           HOWDEN TYPE                      132          132     132  ...
#           KNUCKLE HEAD                       7            7       7  ...
#           MINIATURE                         28           28      28  ...
#           PIE TYPE                         114          114     114  ...
# ST. LOUIS HOWDEN TYPE                        0            0      40  ...
#           HOWDEN WHITE TYPE                  0            0       5  ...
#           MINIATURE                          0            0      38  ...
#           MIXED HEIRLOOM VARIETIES           0            0      10  ...
#           PIE TYPE                           0            0      10  ...
#
#                                     Condition  Appearance  Storage  Crop  \
# City Name Variety
# BALTIMORE BIG MACK TYPE                     0           0        0     0
#           CINDERELLA                        0           0        0     0
#           FAIRYTALE                         0           0        0     0
#           HOWDEN TYPE                       0           0        0     0
#           HOWDEN WHITE TYPE                 0           0        0     0
#           MINIATURE                         0           0        0     0
#           MIXED HEIRLOOM VARIETIES          0           0        0     0
#           PIE TYPE                          0           0        0     0
# BOSTON    BIG MACK TYPE                     0           0        0     0
#           BLUE TYPE                         0           0        0     0
#           CINDERELLA                        0           0        0     0
#           FAIRYTALE                         0           0        0     0
#           HOWDEN TYPE                       0           0        0     0
#           KNUCKLE HEAD                      0           0        0     0
#           MINIATURE                         0           0        0     0
#           PIE TYPE                          0           0        0     0
# ST. LOUIS HOWDEN TYPE                       0           0        0     0
#           HOWDEN WHITE TYPE                 0           0        0     0
#           MINIATURE                         0           0        0     0
#           MIXED HEIRLOOM VARIETIES          0           0        0     0
#           PIE TYPE                          0           0        0     0
#
#                                     Repack  Trans Mode  Offerings  \
# City Name Variety
# BALTIMORE BIG MACK TYPE                 24           0          0
#           CINDERELLA                    25           0          0
#           FAIRYTALE                     16           0          0
#           HOWDEN TYPE                   25           0          0
#           HOWDEN WHITE TYPE              2           0          0
#           MINIATURE                     30           0          0
#           MIXED HEIRLOOM VARIETIES       3           0          0
#           PIE TYPE                      26           0          0
# BOSTON    BIG MACK TYPE                 29           0          0
#           BLUE TYPE                      7           0          0
#           CINDERELLA                    14           0          0
#           FAIRYTALE                     21           0          0
#           HOWDEN TYPE                  132           0          0
#           KNUCKLE HEAD                   7           0          0
#           MINIATURE                     28           0          0
#           PIE TYPE                     114           0          0
# ST. LOUIS HOWDEN TYPE                   40           0          0
#           HOWDEN WHITE TYPE              5           0          0
#           MINIATURE                     38           0          0
#           MIXED HEIRLOOM VARIETIES      10           0          0
#           PIE TYPE                      10           0          0
#
#                                     Market Tone  Price Comment  Comments
# City Name Variety
# BALTIMORE BIG MACK TYPE                       0              0         0
#           CINDERELLA                          0              0         0
#           FAIRYTALE                           0              0         0
#           HOWDEN TYPE                         0              0         0
#           HOWDEN WHITE TYPE                   0              0         0
#           MINIATURE                           0              0         0
#           MIXED HEIRLOOM VARIETIES            0              0         0
#           PIE TYPE                            0              0         0
# BOSTON    BIG MACK TYPE                       0              0         0
#           BLUE TYPE                           0              0         0
#           CINDERELLA                          0              0         0
#           FAIRYTALE                           0              0         0
#           HOWDEN TYPE                         0              0         0
#           KNUCKLE HEAD                        0              0         0
#           MINIATURE                           0              0         0
#           PIE TYPE                            0              0         0
# ST. LOUIS HOWDEN TYPE                        40              0         0
#           HOWDEN WHITE TYPE                   5              0         0
#           MINIATURE                          38              0         0
#           MIXED HEIRLOOM VARIETIES           10              0         0
#           PIE TYPE                           10              0         0
#
# [21 rows x 25 columns]

# %%
df_atl = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/atlanta_9-24-2016_9-30-2017.csv')
df_col = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/columbia_9-24-2016_9-30-2017.csv')
df_mia = pd.read_csv('/Users/bradleytkay/Desktop/LaunchCode/data-analysis-projects/data-manipulation/studio/data-manipulation-studio/dataset/miami_9-24-2016_9-30-2017.csv')

df_atl = df_atl.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 
df_col = df_col.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 
df_mia = df_mia.drop(['Grade', 'Origin District'], axis=1, errors='ignore') 

df_se = pd.concat([df_atl, df_col, df_mia])

df_se_grouped_package = df_se.groupby('Package')
df_se_grouped_package.agg({'Low Price': 'mean', 'High Price': 'mean'})

df_se_grouped_market = df_se.groupby(['City Name', 'Variety'])
df_se_grouped_market.count()
# Out:
#                                     Commodity Name  Type  Package  \
# City Name Variety
# ATLANTA   HOWDEN TYPE                           35     0       35
#           MINIATURE                              1     0        1
#           PIE TYPE                              21     0       21
# COLUMBIA  BLUE TYPE                             11     0       11
#           CINDERELLA                            16     0       16
#           FAIRYTALE                             11     0       11
#           HOWDEN TYPE                           91     0       91
#           HOWDEN WHITE TYPE                      8     0        8
#           KNUCKLE HEAD                          11     0       11
#           MINIATURE                             54     0       54
#           MIXED HEIRLOOM VARIETIES              12     0       12
#           PIE TYPE                              49     0       49
# MIAMI     HOWDEN TYPE                            2     0        2
#           PIE TYPE                               1     0        1
#
#                                     Sub Variety  Date  Low Price  High Price  \
# City Name Variety
# ATLANTA   HOWDEN TYPE                         0    35         35          35
#           MINIATURE                           1     1          1           1
#           PIE TYPE                            0    21         21          21
# COLUMBIA  BLUE TYPE                           0    11         11          11
#           CINDERELLA                          0    16         16          16
#           FAIRYTALE                           0    11         11          11
#           HOWDEN TYPE                         0    91         91          91
#           HOWDEN WHITE TYPE                   0     8          8           8
#           KNUCKLE HEAD                        0    11         11          11
#           MINIATURE                          54    54         54          54
#           MIXED HEIRLOOM VARIETIES            0    12         12          12
#           PIE TYPE                            0    49         49          49
# MIAMI     HOWDEN TYPE                         0     2          2           2
#           PIE TYPE                            0     1          1           1
#
#                                     Mostly Low  Mostly High  Origin  ...  \
# City Name Variety                                                    ...
# ATLANTA   HOWDEN TYPE                       35           35      35  ...
#           MINIATURE                          1            1       1  ...
#           PIE TYPE                          21           21      21  ...
# COLUMBIA  BLUE TYPE                         11           11      11  ...
#           CINDERELLA                        16           16      16  ...
#           FAIRYTALE                         11           11      11  ...
#           HOWDEN TYPE                       91           91      91  ...
#           HOWDEN WHITE TYPE                  8            8       8  ...
#           KNUCKLE HEAD                      11           11      11  ...
#           MINIATURE                         54           54      54  ...
#           MIXED HEIRLOOM VARIETIES          12           12      12  ...
#           PIE TYPE                          49           49      49  ...
# MIAMI     HOWDEN TYPE                        2            2       2  ...
#           PIE TYPE                           1            1       1  ...
#
#                                     Color  Environment  Unit of Sale  Quality  \
# City Name Variety
# ATLANTA   HOWDEN TYPE                   0            0             0        0
#           MINIATURE                     0            0             0        0
#           PIE TYPE                      0            0             0        0
# COLUMBIA  BLUE TYPE                     0            0             0        0
#           CINDERELLA                    0            0             0        0
#           FAIRYTALE                     0            0             0        0
#           HOWDEN TYPE                  68            0             0        0
#           HOWDEN WHITE TYPE             0            0             0        0
#           KNUCKLE HEAD                  0            0             0        0
#           MINIATURE                    54            0             0        0
#           MIXED HEIRLOOM VARIETIES      0            0             0        0
#           PIE TYPE                     39            0             0        0
# MIAMI     HOWDEN TYPE                   0            0             2        0
#           PIE TYPE                      0            0             1        0
#
#                                     Condition  Appearance  Storage  Crop  \
# City Name Variety
# ATLANTA   HOWDEN TYPE                       0           0        0     0
#           MINIATURE                         0           0        0     0
#           PIE TYPE                          0           0        0     0
# COLUMBIA  BLUE TYPE                         0           0        0     0
#           CINDERELLA                        0           0        0     0
#           FAIRYTALE                         0           0        0     0
#           HOWDEN TYPE                       0           0        0     0
#           HOWDEN WHITE TYPE                 0           0        0     0
#           KNUCKLE HEAD                      0           0        0     0
#           MINIATURE                         0           0        0     0
#           MIXED HEIRLOOM VARIETIES          0           0        0     0
#           PIE TYPE                          0           0        0     0
# MIAMI     HOWDEN TYPE                       0           0        0     0
#           PIE TYPE                          0           0        0     0
#
#                                     Repack  Trans Mode
# City Name Variety
# ATLANTA   HOWDEN TYPE                   35           0
#           MINIATURE                      1           0
#           PIE TYPE                      21           0
# COLUMBIA  BLUE TYPE                     11           0
#           CINDERELLA                    16           0
#           FAIRYTALE                     11           0
#           HOWDEN TYPE                   91           0
#           HOWDEN WHITE TYPE              8           0
#           KNUCKLE HEAD                  11           0
#           MINIATURE                     54           0
#           MIXED HEIRLOOM VARIETIES      12           0
#           PIE TYPE                      49           0
# MIAMI     HOWDEN TYPE                    2           0
#           PIE TYPE                       1           0
#
# [14 rows x 21 columns]
